# %%
import numpy as np
import xarray as xr
import uxarray as ux
import yaml
import cartopy
import holoviews as hv
import hvplot.pandas
from matplotlib import pyplot as plt, colors

# Set plot font sizes
plt.rcParams.update({'font.size': 14, 'axes.titlesize': 'medium'})

# %matplotlib inline
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="a37d8fcf-6c77-4fd3-bd6a-78c3919d8162" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Get paths
with open('../yaml/paths_HR.yaml', 'r') as f:
    paths = yaml.safe_load(f)

# %%
bbox = [-100, 50, 39, 85]

uxda = ux.open_dataset(paths['meshfile'], paths['meshfile'])['bottomDepth'].subset.bounding_box(bbox[:2], bbox[2:])
gdf_data = uxda.to_geodataframe()
hv.extension('matplotlib')
projection = cartopy.crs.LambertConformal(-20, 70)

plot = gdf_data.hvplot.polygons(
    c='bottomDepth', cmap='Blues',
    colorbar=True, clabel='Bottom depth [m]',
    width=6000, height=6000,
    projection=projection,
    rasterize=True,
)
# cbar_extend='neither', cbar_width=0.02
plot.opts(cbar_extend='neither', cbar_width=0.02, bgcolor='lightgray', norm='log', clim=(1, 5000), xlim=(-60, 10), ylim=(45, 80), title='High Resolution (HR)')

fig = hv.render(plot)
fig.set_size_inches((8, 8))
# Out:
# /global/u1/b/bmoorema/mambaforge/envs/dev_compass_1.2.0-alpha.5/lib/python3.10/site-packages/uxarray/grid/geometry.py:88: UserWarning: Converting to a GeoDataFrame with over 1,000,000 faces may take some time.
#   warnings.warn(
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1009'>
#   <div id="f6337d23-ab7f-4553-9945-429225369a31" data-root-id="p1009" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
fig

# %%
fig.savefig('/pscratch/sd/b/bmoorema/posterfigs/HR_meshplot.png', dpi=600, bbox_inches='tight')
