# %% [markdown]
# # MPAS-Ocean water mass analysis: 2D formation seasonal
#
# ## Ten-year averages (1947-1956, 1997-2006)
#
# LR (`60to30E2r2`) and HR (`18to6v3`) CORE-forced 20-21st century simulations (Cycle 1)
#
# ***

# %%
import xarray as xr
import matplotlib.pyplot as plt
import sys
from dateutil.parser import parse

# Import modules from path
sys.path.append('../modules/')
import visualizationtools as viz

# Set plot font sizes
plt.rcParams.update({'font.size': 10, 'axes.titlesize': 'medium'})

# %% [markdown]
# ***
#
# ## Load results
#
# Define paths, parameters and load aggregated netCDF files. Files were produced using [build_mpas_2Dtimeavgs.py](https://github.com/MPAS-Dev/MPAS-QuickViz/blob/master/ocean/AMOC/watermassanalysis/modules/build_mpas_2Dtimeavgs.py).

# %%
# Path, meshes and timeranges
resultspath = '/pscratch/sd/b/bmoorema/results/aggregated/lonlat/'
meshes = ['EC30to60E2r2', 'oRRS18to6v3']
timeranges = [
    ('1947 Jan 1', '1956 Dec 31'),
    ('1997 Jan 1', '2006 Dec 31'),
]
timeranges = [[parse(t) for t in trange] for trange in timeranges]

# Loop though meshes and timeranges
ds = {mesh: {} for mesh in meshes}
for mesh in meshes:
    for timerange in timeranges:
        
        # Construct strings and load 2D fields via xarray
        tstr = '_'.join(date.strftime('%Y%m%d') for date in timerange)
        fn = resultspath + '20210421_sim7_CORE_' + mesh + '.mpas2Dtimeavg_wmtf_' + tstr + '.nc'
        tstr = '-'.join(str(date.year) for date in timerange)
        ds[mesh][tstr] = xr.open_dataset(fn)

# %% [markdown]
# ***
#
# ## Seasonal formation plots
#
# ### STMW ($\sigma_{\theta}$ = 26.2 to 27)

# %%
# STMW plot args
varname, units, clims = 'totalForm', '10$^{-12}$ Sv m$^{-2}$', [-100, 100, 100]
sigmabins = slice(26.2, 27)

# %% [markdown]
# **Annual average**

# %%
# Plot STMW formation (annual average)
fig, axs = viz.plot_2Dvariable(ds, varname, units, sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# **Dec-Feb**

# %%
# Plot STMW formation (DJF)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[12, 1, 2], sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# **Mar-May**

# %%
# Plot STMW formation (MAM)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[3, 4, 5], sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# **Jun-Aug**

# %%
# Plot STMW formation (JJA)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[6, 7, 8], sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# **Sep-Nov**

# %%
# Plot STMW formation (SON)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[9, 10, 11], sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# ***
#
# ### SPMW ($\sigma_{\theta}$ = 27.3 to 28.5)

# %%
# SPMW plot args
varname, units, clims = 'totalForm', '10$^{-12}$ Sv m$^{-2}$', [-100, 100, 100]
sigmabins = slice(27.3, 28.5)

# %% [markdown]
# **Annual average**

# %%
# Plot SPMW formation (annual average)
fig, axs = viz.plot_2Dvariable(ds, varname, units, sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# **Dec-Feb**

# %%
# Plot SPMW formation (DJF)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[12, 1, 2], sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# **Mar-May**

# %%
# Plot SPMW formation (MAM)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[3, 4, 5], sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# **Jun-Aug**

# %%
# Plot SPMW formation (JJA)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[6, 7, 8], sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# **Sep-Nov**

# %%
# Plot SPMW formation (SON)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[9, 10, 11], sigmabins=sigmabins, clims=clims, cmap='BrBG_r')

# %% [markdown]
# ***
#
# ## Sigma-binned formation plots
#
# ### SPMW (Dec-Feb)

# %%
# SPMW plot args
varname, units, clims = 'totalForm', '10$^{-12}$ Sv m$^{-2}$', [-100, 100, 100]

# %% [markdown]
# **$\sigma_{\theta}$ = 27.3-27.5**

# %%
# Plot STMW formation (27.3-27.5)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[12, 1, 2], sigmabins=slice(27.3, 27.5), clims=clims, cmap='BrBG_r')

# %% [markdown]
# **$\sigma_{\theta}$ = 27.6-27.8**

# %%
# Plot STMW formation (27.6-27.8)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[12, 1, 2], sigmabins=slice(27.6, 27.8), clims=clims, cmap='BrBG_r')

# %% [markdown]
# **$\sigma_{\theta}$ = 27.9-28.1**

# %%
# Plot STMW formation (27.9-28.1)
fig, axs = viz.plot_2Dvariable(ds, varname, units, months=[12, 1, 2], sigmabins=slice(27.9, 28.1), clims=clims, cmap='BrBG_r')
